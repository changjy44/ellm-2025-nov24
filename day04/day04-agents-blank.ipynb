# %% [markdown]
# # IMPORTANT
#
# Run the following to install smolagents

# %%
# Imports
import os

from smolagents import CodeAgent, OpenAIServerModel
from dotenv import load_dotenv

# %%
# TODO: Import the tools notebook
# %run day04-tools-blank.ipynb
# Out:
#    id      country            city   latitude  longitude  altitude
# 0   2  Afghanistan        Kandahar  31.610000  65.699997      1015
# 1   3  Afghanistan  Mazar-e Sharif  36.706944  67.112221       369
# 2   4  Afghanistan           Herat  34.340000  62.189999       927
# 3   5  Afghanistan       Jalalabad  34.420000  70.449997       573
# 4   6  Afghanistan          Konduz  36.720000  68.860001       394
#
# Empty DataFrame
# Columns: [id, country, city, latitude, longitude, altitude]
# Index: []
# {'temperature_unit': '°C', 'temperature': 14.6}
# [(1, 'For Those About To Rock We Salute You', 'For Those About To Rock (We Salute You)', 'AC/DC', 343719, 'Angus Young, Malcolm Young, Brian Johnson'), (2, 'Balls to the Wall', 'Balls to the Wall', 'Accept', 342562, None), (3, 'Restless and Wild', 'Fast As a Shark', 'Accept', 230619, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman'), (3, 'Restless and Wild', 'Restless and Wild', 'Accept', 252051, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman'), (3, 'Restless and Wild', 'Princess of the Dawn', 'Accept', 375418, 'Deaffy & R.A. Smith-Diesel'), (1, 'For Those About To Rock We Salute You', 'Put The Finger On You', 'AC/DC', 205662, 'Angus Young, Malcolm Young, Brian Johnson'), (1, 'For Those About To Rock We Salute You', "Let's Get It Up", 'AC/DC', 233926, 'Angus Young, Malcolm Young, Brian Johnson'), (1, 'For Those About To Rock We Salute You', 'Inject The Venom', 'AC/DC', 210834, 'Angus Young, Malcolm Young, Brian Johnson'), (1, 'For Those About To Rock We Salute You', 'Snowballed', 'AC/DC', 203102, 'Angus Young, Malcolm Young, Brian Johnson'), (1, 'For Those About To Rock We Salute You', 'Evil Walks', 'AC/DC', 263497, 'Angus Young, Malcolm Young, Brian Johnson')]

# %%
# TODO: Get the Huggingface token
# IMPORTANT: Before you run this cell, create a file called .env in day04 directory 
# and add the following line into the file
# OPENAI_API_KEY=OpenAI_API_key
result = load_dotenv()
print(result)

KEY = os.getenv('OPENAI_API_KEY')
#print(KEY)
# Out:
# True

# %%
# TODO: Load an agent
model_id = 'gpt-4.1-mini'

# Load the GPT model
model = OpenAIServerModel(model_id=model_id, api_key=KEY)

# Build the agent with the default tools, with additinoal imports. Use this with caution!
agent = CodeAgent(tools=[], model=model, add_base_tools=True, additional_authorized_imports=[ 'sympy' ])

# %%
# TODO: List of tools 
for t in agent.tools.keys():
   print(t)
# Out:
# web_search
# visit_webpage
# final_answer

# %%
# TODO Run a simple query 
agent.run('What is the integral of x^3?', max_steps=3)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the integral of x^3?                                                                                    │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import sympy as sp
#
#   x = sp.symbols('x')
#   integral_result = sp.integrate(x**3, x)
#   final_expr = integral_result + sp.symbols('C')  # Add the constant of integration
#   final_answer(str(final_expr))
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: C + x**4/4
# [Step 1: Duration 3.33 seconds| Input tokens: 2,084 | Output tokens: 134]
# 'C + x**4/4'

# %%
# TODO: Create an agent with our own tools
# List of our tools
tools = [ get_latlng, get_temperature, SQLiteTool('./data/chinook_sqlite.sqlite')]
agent = CodeAgent(tools=tools, model=model, add_base_tools=True)

# %%
for t in agent.tools.keys():
   print(t)
# Out:
# get_latlng
# get_temperature
# album_database
# web_search
# visit_webpage
# final_answer

# %%
# TODO: Perform a search with DuckDuckGo
agent.run('what is the temperature in Clementi?', max_steps=5)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ what is the temperature in Clementi?                                                                            │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Get the latitude, longitude and altitude for Clementi
#   location = get_latlng("Clementi")
#   print(location)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'location = get_latlng("Clementi")' due to: IndexError: single positional indexer is
# out-of-bounds
# [Step 1: Duration 1.63 seconds| Input tokens: 2,197 | Output tokens: 72]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Try to get the latitude and longitude for Clementi, Singapore instead
#   location = get_latlng("Clementi, Singapore")
#   print(location)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'location = get_latlng("Clementi, Singapore")' due to: IndexError: single positional
# indexer is out-of-bounds
# [Step 2: Duration 1.87 seconds| Input tokens: 4,603 | Output tokens: 177]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Get the latitude and longitude for Singapore
#   singapore_location = get_latlng("Singapore")
#   print(singapore_location)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# {'city': 'Singapore', 'latitude': np.float64(1.29027), 'longitude': np.float64(103.851959), 'altitude':
# np.int64(164)}
#
# Out: None
# [Step 3: Duration 2.05 seconds| Input tokens: 7,258 | Output tokens: 269]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   latitude = singapore_location['latitude']
#   longitude = singapore_location['longitude']
#
#   # Get the temperature for Singapore coordinates
#   temperature_info = get_temperature(latitude, longitude)
#   print(temperature_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# {'temperature_unit': '°C', 'temperature': 27.9}
#
# Out: None
# [Step 4: Duration 2.31 seconds| Input tokens: 10,126 | Output tokens: 347]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("The temperature in Clementi is approximately 27.9 °C.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: The temperature in Clementi is approximately 27.9 °C.
# [Step 5: Duration 1.44 seconds| Input tokens: 13,187 | Output tokens: 413]
# 'The temperature in Clementi is approximately 27.9 °C.'

# %%
# TODO: Perform task with get_latlng and get_temperature function
# TODO: Will switch to duckduckgo if cannot get the temperature from custom functions

# %%
#TODO: Rerun the query
band = "michael jackson"
#band = "men At work"
# band = 'james brown'
prompt = f""" 
List 10 songs by the band {band}.
""" 

agent.run(prompt, max_steps=5)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ List 10 songs by the band michael jackson.                                                                      │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = """
#   SELECT track_name
#   FROM album_track
#   WHERE artist_name = 'Michael Jackson'
#   LIMIT 10
#   """
#   songs = album_database(query=query)
#   print(songs)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# []
#
# Out: None
# [Step 1: Duration 1.67 seconds| Input tokens: 2,302 | Output tokens: 101]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query_artists = """
#   SELECT DISTINCT artist_name
#   FROM album_track
#   WHERE artist_name LIKE '%Michael%'
#   LIMIT 10
#   """
#   artists_sample = album_database(query=query_artists)
#   print(artists_sample)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# [('Michael Tilson Thomas & San Francisco Symphony',)]
#
# Out: None
# [Step 2: Duration 1.75 seconds| Input tokens: 4,803 | Output tokens: 212]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query_artists_jackson = """
#   SELECT DISTINCT artist_name
#   FROM album_track
#   WHERE artist_name LIKE '%Jackson%'
#   LIMIT 10
#   """
#   artists_jackson_sample = album_database(query=query_artists_jackson)
#   print(artists_jackson_sample)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# []
#
# Out: None
# [Step 3: Duration 2.51 seconds| Input tokens: 7,532 | Output tokens: 341]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query_random_artists = """
#   SELECT artist_name, track_name
#   FROM album_track
#   LIMIT 100
#   """
#   samples = album_database(query=query_random_artists)
#   michael_jackson_songs = [track for artist, track in samples if "Michael Jackson" in artist]
#   print(michael_jackson_songs[:10])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# []
#
# Out: None
# [Step 4: Duration 2.77 seconds| Input tokens: 10,504 | Output tokens: 486]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query_tracks_michael = """
#   SELECT track_name, artist_name
#   FROM album_track
#   WHERE track_name LIKE '%Michael%'
#   LIMIT 10
#   """
#   tracks_michael = album_database(query=query_tracks_michael)
#   print(tracks_michael)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# [("Michael's Birthday", 'The Office')]
#
# Out: None
# [Step 5: Duration 2.15 seconds| Input tokens: 13,747 | Output tokens: 594]
# Reached max steps.
# [Step 6: Duration 5.40 seconds| Input tokens: 15,003 | Output tokens: 719]
# 'Michael Jackson is a solo artist, not a band, and is widely known as the "King of Pop." Here are 10 popular songs by Michael Jackson:\n\n1. Billie Jean  \n2. Thriller  \n3. Beat It  \n4. Smooth Criminal  \n5. Man in the Mirror  \n6. Bad  \n7. Black or White  \n8. Dirty Diana  \n9. The Way You Make Me Feel  \n10. Don\'t Stop \'Til You Get Enough\n\nIf you meant to ask for songs by Michael Jackson, these are some of his most famous tracks. If you were referring to another band or artist, please clarify.'
